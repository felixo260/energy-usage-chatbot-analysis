# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Jupyter is working inside VS Code")
# Out:
# Jupyter is working inside VS Code

# %%
customer_df = pd.read_csv("../DATASETS/tragerinc_customer_info.csv")
energy_df = pd.read_csv("../DATASETS/tragerinc_energy_usage.csv")
chatbot_df = pd.read_csv("../DATASETS/tragerinc_chatbot_interactions.csv")
support_df = pd.read_csv("../DATASETS/tragerinc_support_tickets.csv")

print("Customer:", customer_df.shape)
print("Energy:", energy_df.shape)
print("Chatbot:", chatbot_df.shape)
print("Support:", support_df.shape)
# Out:
# Customer: (10000, 8)
# Energy: (216276, 6)
# Chatbot: (27202, 6)
# Support: (10940, 7)
